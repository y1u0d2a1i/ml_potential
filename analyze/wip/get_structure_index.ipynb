# %%
import pandas as pd
import numpy as np
import os

# %%
path2target = '/Users/y1u0d2/desktop/Lab/result/n2p2/Si/07/rc_5-np_9'

# %%
with open(os.path.join(path2target, 'input.data'), mode='r') as f:
    l_strip = [s.strip() for s in f.readlines()]
    
all_data = list(filter(lambda x: 'comment' in x, l_strip))

# %%
with open(os.path.join(path2target, 'test.data'), mode='r') as f:
    l_strip = [s.strip() for s in f.readlines()]
    
test_data = list(filter(lambda x: 'comment' in x, l_strip))

# %%
with open(os.path.join(path2target, 'train.data'), mode='r') as f:
    l_strip = [s.strip() for s in f.readlines()]
    
train_data = list(filter(lambda x: 'comment' in x, l_strip))

# %%
all_df = pd.DataFrame(data=all_data, columns=['comment'])

# %%
all_df = all_df.reset_index()
all_df = all_df.rename(columns={'index': 'structure_idx'})

# %%
test_df = pd.DataFrame(data=test_data, columns=['comment'])
train_df = pd.DataFrame(data=train_data, columns=['comment'])

# %%
test_structure_ids = pd.merge(all_df, test_df, on='comment', how='right')
train_structure_ids = pd.merge(all_df, train_df, on='comment', how='right')

# %%
def get_materials_id_from_comment(val):
    splitted_path = val.split('/')
    id = list(filter(lambda x: 'mp-' in x, splitted_path))[0]
    return id

test_structure_ids['materials_id'] = test_structure_ids['comment'].map(get_materials_id_from_comment)
train_structure_ids['materials_id'] = train_structure_ids['comment'].map(get_materials_id_from_comment)

# %%
test_structure_ids
# Out:
#      structure_idx                                            comment  \
# 0              165  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 1              369  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 2              446  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 3              564  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 4              578  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# ..             ...                                                ...
# 285           2403  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 286           2489  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 287           2598  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 288           2691  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 289           2717  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
#
#     materials_id
# 0     mp-1079649
# 1     mp-1079649
# 2     mp-1079649
# 3         mp-109
# 4         mp-109
# ...

# %%
train_structure_ids
# Out:
#       structure_idx                                            comment  \
# 0                 2  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 1                 3  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 2                33  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 3                44  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 4                72  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# ...             ...                                                ...
# 2692           2678  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 2693           2718  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 2694           2767  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 2695           2783  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 2696           2810  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
#
#      materials_id
# 0      mp-1079649
# 1      mp-1079649
# 2      mp-1079649
# 3      mp-1079649
# ...

# %%
from analyze.get_structure_index import get_structure_idx

path2target = '/Users/y1u0d2/desktop/Lab/result/n2p2/Si/07/rc_5-np_9'
test_structure_idx, train_structure_idx = get_structure_idx(path2target)

# %%
test_structure_idx
# Out:
#      structure_idx                                            comment  \
# 0              165  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 1              369  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 2              446  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 3              564  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 4              578  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# ..             ...                                                ...
# 285           2403  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 286           2489  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 287           2598  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 288           2691  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
# 289           2717  comment /Users/y1u0d2/desktop/Lab/result/qe/Si...
#
#     materials_id
# 0     mp-1079649
# 1     mp-1079649
# 2     mp-1079649
# 3         mp-109
# 4         mp-109
# ...
